# %%
import pandas as pd
import numpy as np

# %%
movie = pd.read_csv("F:\Desktop\Kaustubh\DataScience\RadicalTechnologies\Pig\movieDataAnalysis\moviesData.csv", encoding = 'latin-1', header=None, names=['movieId','movieName','releaseYear','rating','duration'])

# %%
movie
# Out:
#        movieId                                          movieName  \
# 0            1                     The Nightmare Before Christmas
# 1            2                                          The Mummy
# 2            3                               Orphans of the Storm
# 3            4                               The Object of Beauty
# 4            5                                         Night Tide
# 5            6                                One Magic Christmas
# 6            7                                   Muriel's Wedding
# 7            8                                      Mother's Boys
# 8            9                        Nosferatu: Original Version
# 9           10                                       Nick of Time
# 10          11                                    Broken Blossoms
# 11          12                                          Big Night
# 12          13                              The Birth of a Nation
# ...

# %%
print(movie['movieName'])
# Out:
# 0                           The Nightmare Before Christmas
# 1                                                The Mummy
# 2                                     Orphans of the Storm
# 3                                     The Object of Beauty
# 4                                               Night Tide
# 5                                      One Magic Christmas
# 6                                         Muriel's Wedding
# 7                                            Mother's Boys
# 8                              Nosferatu: Original Version
# 9                                             Nick of Time
# 10                                         Broken Blossoms
# 11                                               Big Night
# 12                                   The Birth of a Nation
# 13                                    The Boys from Brazil
# 14                                          Big Doll House
# 15                                      The Breakfast Club
# ...

# %%
print(movie['releaseYear'])
# Out:
# 0        1993
# 1        1932
# 2        1921
# 3        1991
# 4        1963
# 5        1985
# 6        1994
# 7        1994
# 8        1929
# 9        1995
# 10       1919
# 11       1996
# 12       1915
# 13       1978
# 14       1971
# 15       1985
# 16       1935
# 17       1996
# 18       1981
# 19       1971
# 20       1989
# 21       1987
# 22       1994
# 23       1996
# 24       1986
# 25       1986
# 26       1996
# 27       1972
# 28       1994
# 29       1992
#          ...
# 49560    2014
# 49561    2013
# 49562    2013
# 49563    2013
# 49564    2013
# 49565    2013
# 49566    2013
# 49567    2013
# 49568    2013
# 49569    2013
# 49570    2013
# 49571    2013
# 49572    2013
# 49573    2013
# 49574    2013
# 49575    2013
# 49576    2013
# 49577    2013
# 49578    2013
# 49579    2012
# 49580    2009
# 49581    1996
# 49582    2013
# 49583    2012
# 49584    2013
# 49585    2013
# 49586    2013
# 49587    2010
# 49588    2010
# 49589    2010
# ...

# %%
movie.releaseYear

# %%
print(movie.loc[movie['releaseYear']==[1950]])

# %%
# Selcting the movies released in the year 1950 to 1960
movies_1950_to_1960 = movie[(movie.releaseYear >= 1950) & (movie.releaseYear <= 1960)]
len(movies_1950_to_1960)
# Out:
# 547

# %%
movies_1950_to_1960
# Out:
# 547

# %%
movies_rating_more_than_4 = movie[movie.rating >= 4]

# %%
movies_rating_more_than_4

# %%
movies_rating_3_to_4 = movie[(movie.rating >= 3) & (movie.rating <=4)]

# %%
movies_rating_3_to_4

# %%
movies_duration_more_than_7200_secs = movie[movie.duration > 7200]

# %%
movies_duration_more_than_7200_secs

# %%
number_of_movies_in_dataset = len(movie.movieId)

# %%
number_of_movies_in_dataset
# Out:
# 49590

# %%
# List of Movies in Each Year
print(movie.iloc[:, 2].value_counts())
# Out:
# 2011    5511
# 2010    5107
# 2009    4451
# 2012    4339
# 2008    3358
# 2007    2892
# 2006    2416
# 2005    1937
# 2003    1399
# 2004    1381
# 1999    1181
# 2001    1173
# 2002    1117
# 2013     981
# 2000     902
# 1998     843
# 1997     788
# 1996     688
# 1995     592
# 1993     564
# 1994     517
# 1992     479
# 1990     470
# 1989     421
# 1991     364
# 1988     334
# 1985     334
# 1984     303
# 1986     287
# 1987     280
#         ...
# 1949       9
# 1934       8
# 1943       7
# 1936       7
# 1933       7
# 1941       7
# 1939       6
# 1946       6
# 1920       6
# 1938       5
# 1925       5
# 1930       5
# 1924       5
# 1929       5
# 1927       4
# 1937       4
# 1923       4
# 1932       4
# 1931       3
# 1913       3
# 1919       3
# 1942       3
# 1926       2
# 1922       2
# 1928       2
# 1921       2
# 1918       1
# 1916       1
# 1915       1
# 2014       1
# Name: releaseYear, Length: 101, dtype: int64
